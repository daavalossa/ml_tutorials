# %% [markdown]
# # Análisis de Sentimiento con NLTK
#
# El análisis de sentimiento es una de las tareas más populares en NLP. Hay mucha literatura y casos prácticos que rodean este tema, por lo que también hay varios proveedores que ofrecen productos relacionados. Sin embargo, crear un módulo de análisis de sentimiento básico es relativamente sencillo.
#
# En este tutorial realizaremos un análisis de sentimiento para los *reviews* de celulares comprados en la plataforma AMAZON. El modelo de sentimiento está basado en algunos de los métodos que ofrece NLTK, los cuales se describen más adelante.
#
# # Empezamos cargando los datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.utils import shuffle
import nltk

# %%
# Cargamos los datos 
url = 'https://raw.githubusercontent.com/patofw/imf_master/master/Notebooks/data/amazon_mobile_sales_short.csv'
data = pd.read_csv( url)
data.head()
# Out:
#                                         Product Name  Brand Name   Price  \
# 0  LG G3 Vigor D725 8GB Unlocked GSM 4G LTE Quad-...          LG  123.64
# 1  CNPGD [U.S. Office Extended Warranty] Smartwat...       CNPGD   49.99
# 2  Apple iPhone 5s 16GB (Space Gray) - Verizon Wi...       Apple  149.99
# 3  BlackBerry Bold 9700 Unlocked GSM 3G World Pho...  BlackBerry  101.99
# 4  BLU Advance 4.0L Unlocked Smartphone -US GSM -...         BLU   47.97
#
#    Rating                                            Reviews  Review Votes
# 0       5                                          I like it           0.0
# 1       5    CNPGD All-in-1 Watch Cell Phone & Smart...CNPGD           0.0
# 2       5                                          Thank you           0.0
# 3       5  I bought 2sets.It arrived early enough as usua...           0.0
# 4       5  This is really a good Smartphone! It has been ...           0.0

# %%
# Describimos el dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  75000 non-null  object
#  1   Brand Name    75000 non-null  object
#  2   Price         74116 non-null  float64
#  3   Rating        75000 non-null  int64
#  4   Reviews       74990 non-null  object
#  5   Review Votes  72910 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.4+ MB

# %%
data.drop('Review Votes', inplace=True, axis=1) # Eliminamos esta columna que no usaremos.
# eliminamos nulos por conveniencia 
data.dropna(inplace=True)

# %%
# Exploración rápida 
plt.rcParams['figure.figsize'] = (18, 7) # parametros de la viz
sns.boxenplot(data=data, 
            x='Brand Name',
            y='Rating')
plt.title('Rating por Marca', fontsize = 20)
plt.xticks(rotation='vertical')
plt.show();

# %%
sns.barplot(data=data, 
            x='Brand Name',
            y='Rating')
# Out:
# <AxesSubplot:xlabel='Brand Name', ylabel='Rating'>

# %% [markdown]
# # El Corpus
#
# Como siempre, realizaremos transformaciones que nos permitan limpiar el corpus.

# %%
data.Reviews.values[:5]
# Out:
# array(['I like it', 'CNPGD All-in-1 Watch Cell Phone & Smart...CNPGD',
#        'Thank you',
#        "I bought 2sets.It arrived early enough as usual. All the contents were accounted for and i am very happy with my purchase.I have read about the 'P' key falling off after 3weeks...i haven't yet gotten to that point but will definitely update my post if anything negative crops up. I highly recommend updating the device software before use!",
#        'This is really a good Smartphone! It has been working perfectly! I have no complaints at all. Thank you!'],
#       dtype=object)

# %%
from time import time # Medimos tiempo de ejecución
import re 

import spacy

nlp = spacy.load('en', disable=['ner', 'parser']) # Quitamos el Named Entity Recognition por facilidad de procesamiento

def cleaning(doc):
    # Lemmatiza y elimina stopwords
    # Necesitamos un doc como lo describe spacy
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec usa el contexto para entender la reperesentacion de la palabra
    # Si la oracion es corta, no va a aprender mucho
    return ' '.join(txt)
# Reemplazamos todo lo que no sea alphanum
brief_cleaning = (re.sub(r"[^A-Za-z' ]+", ' ', 
                         str(row)).lower().strip() for row in data.Reviews)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\davalos\Dropbox\PC\Documents\GitHub\ml_tutorials\NLP\Sentiment_Analysis_NLTK.ipynb Celda 10 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> import re
#       <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> import spacy
# ----> <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> nlp = spacy.load('en', disable=['ner', 'parser']) # Quitamos el Named Entity Recognition por facilidad de procesamiento
#       <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> def cleaning(doc):
#       <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>     # Lemmatiza y elimina stopwords
#      <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>     # Necesitamos un doc como lo describe spacy
#      <a href='vscode-notebook-cell:/c%3A/Users/davalos/Dropbox/PC/Documents/GitHub/ml_tutorials/NLP/Sentiment_Analysis_NLTK.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a>     txt = [token.lemma_ for token in doc if not token.is_stop]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\spacy\__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\spacy\util.py:438, in load_model(name, vocab, disable, enable, exclude, config)
#     436     return load_model_from_path(name, **kwargs)  # type: ignore[arg-type]
#     437 if name in OLD_MODEL_SHORTCUTS:
# --> 438     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
#     439 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E941] Can't find model 'en'. It looks like you're trying to load a model from a shortcut, which is obsolete as of spaCy v3.0. To load the model, use its full name instead:
#
# nlp = spacy.load("en_core_web_sm")
#
# For more details on the available models, see the models directory: https://spacy.io/models. If you want to create a blank model, use spacy.blank: nlp = spacy.blank("en")

# %%
# Usamos el método Pipe de Spacy para procesar con mayor velocidad
t = time() # Calculamos tiempo

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, # función que def antes
                                         batch_size=5000, 
                                         n_threads=-1 # usamos todos los cores
                                         )]
t_ = round((time() - t) / 60, 2) # Tiempo de ejecucion en mins
print(f'Tiempo de ejecución: {t_} mins')
# Out:
# Tiempo de ejecución: 1.65 mins

# %%
txt[:5]
# Out:
# ['like',
#  'cnpgd   watch cell phone    smart cnpgd',
#  'thank',
#  "buy   set arrive early usual   content account happy purchase read ' p ' key fall   week get point definitely update post negative crop   highly recommend update device software use",
#  'good smartphone   work perfectly   complaint   thank']

# %% [markdown]
# # El modelo de Sentimiento de NLTK
#
#
# NLTK tiene mucho desarrollo en el análisis de sentimiento. Es más, tiene un [módulo entero](https://www.nltk.org/api/nltk.sentiment.html) para este tipo de casos.
#
# Para este tutorial utilizaremos la función de SentimentIntensityAnalyzer que no solo devuelve un 'valor de sentimiento', pero también incluye otras funciones útiles como cálculo de la polaridad y diferentes formas de normalización de las valencias del cálculo. Además, incluye un diccionario de negaciones que hacen más robusta a esta solución.
#
# El algoritmo está basado en [VADER](https://www.researchgate.net/publication/275828927_VADER_A_Parsimonious_Rule-based_Model_for_Sentiment_Analysis_of_Social_Media_Text) (Valence Aware Dictionary and sEntiment Reasoner) que básicamente es un diccionario de palabras comúnmente utilizadas a las cuales se les asigna un valor de sentimiento ('Good':3, 'Bad':-3).
#
# Este sistema es práctico, simple y funciona. Sin embargo, no debe considerarse como el estado del arte en análisis de sentimiento.
#
# ### Algunos retos a considerar:
# - Frases con doble intención: “The intent behind the movie was great, but it could have been better”.
# - Sarcasmo : 'Great service!!! I had to wait for two hours on the phone. It shows that you really care for your customers!!.
# - Errores gramaticales
# - Polaridad extrema (Sobre todo en política)
# - Bots y Trolls
# - *Slang* y dialectos.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# True

# %%
# Ejemplo de uso
sent = SentimentIntensityAnalyzer()
sent.polarity_scores('It was a very good meal, Im happy')
# Out:
# {'compound': 0.7841, 'neg': 0.0, 'neu': 0.42, 'pos': 0.58}

# %%
sent.polarity_scores('It hated it, worst experience of my life')
# Out:
# {'compound': -0.8519, 'neg': 0.58, 'neu': 0.42, 'pos': 0.0}

# %%
from tqdm.notebook import tqdm # barra de progreso
# Extraemos los sentimientos de cada uno de los reviews
sentiments = [sent.polarity_scores(review) for review in tqdm(txt)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=74106.0), HTML(value='')))

# %%
# Tenemos el diccionario completo, en caso de querer 
# Utilizar algunas de las otras valencias 
sentiments[:2]
# Out:
# [{'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  {'compound': 0.4019, 'neg': 0.0, 'neu': 0.649, 'pos': 0.351}]

# %%
# Sacamos los valores 
values = [d['compound'] for d in sentiments]

# %%
# Lo reinsertamos al dataset 
data['valor_sentimiento'] = values

# %%
data.head()
# Out:
#                                         Product Name  ... valor_sentimiento
# 0  LG G3 Vigor D725 8GB Unlocked GSM 4G LTE Quad-...  ...            0.3612
# 1  CNPGD [U.S. Office Extended Warranty] Smartwat...  ...            0.4019
# 2  Apple iPhone 5s 16GB (Space Gray) - Verizon Wi...  ...            0.3612
# 3  BlackBerry Bold 9700 Unlocked GSM 3G World Pho...  ...            0.6697
# 4  BLU Advance 4.0L Unlocked Smartphone -US GSM -...  ...            0.8126
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Revisamos resultados

# %%
# Correlación 
data[['valor_sentimiento','Rating']].corr()
# Out:
#                    valor_sentimiento    Rating
# valor_sentimiento           1.000000  0.537247
# Rating                      0.537247  1.000000

# %%
data.groupby('Rating')['valor_sentimiento'].mean()
# Out:
# Rating
# 1   -0.082085
# 2    0.121143
# 3    0.317204
# 4    0.526211
# 5    0.573033
# Name: valor_sentimiento, dtype: float64

# %%
# Visualizamos la relación con un mapa de calor 
g = data.groupby(['Rating','Brand Name'])['valor_sentimiento'].mean().unstack()
sns.heatmap(g,
            linewidths=.5, 
            cmap="RdYlGn", 
            vmin = -0.5,
            vmax = .6)
plt.title('Heatmap Valor Sentimiento vs Rating por Marca');

# %%
data.sort_values('Rating').head(10)
# Out:
#                                             Product Name  ... valor_sentimiento
# 74999  LG Nexus 5X Unlocked Smartphone - White 32GB (...  ...            0.0000
# 31909  LG A275 Black Unlocked GSM Dual SIM QuadBand C...  ...            0.6705
# 31908  Samsung Galaxy S4 i9505 16GB LTE Unlocked Inte...  ...           -0.9217
# 57611  BLU Advance 4.0L Unlocked Smartphone -Global G...  ...           -0.2023
# 57612  Motorola Droid 3 Verizon Xt862 Verizon Cell Phone  ...           -0.2732
# 12130  Samsung Galaxy S II Skyrocket I727 16GB Unlock...  ...           -0.6705
# 31903  Samsung Galaxy J7 SM- J700H/DS GSM Smartphone-...  ...            0.0000
# 12134  Blu Dash JR D141W Dual Sim Factory Unlocked An...  ...           -0.5423
# 12135  BlackBerry 8520 Unlocked Phone with 2 MP Camer...  ...           -0.7239
# 57616  BLU Advance 4.0L Unlocked Smartphone -Global G...  ...           -0.0516
#
# [10 rows x 6 columns]

# %%
data.sort_values('Rating', ascending=False).head(10)
# Out:
#                                             Product Name  ... valor_sentimiento
# 0      LG G3 Vigor D725 8GB Unlocked GSM 4G LTE Quad-...  ...            0.3612
# 42578              Apple iPhone 4 32GB (Black) - Verizon  ...            0.9186
# 42565  BlackBerry Storm 2 9550 Unlocked Phone - No Wa...  ...            0.5719
# 42566  BLU Life XL - LTE Smartphone - GSM Unlocked - ...  ...            0.0000
# 42567  BLU PURE XL Smartphone - 4G LTE GSM Unlocked -...  ...            0.7906
# 42569  Samsung Galaxy J7 SM- J700H/DS GSM Smartphone-...  ...            0.4404
# 42571              Apple iPhone 5c 32GB (White) - Sprint  ...            0.9169
# 42572  Samsung Galaxy S4 SGH-I337 Unlocked GSM Smartp...  ...            0.8402
# 42573     Blackberry Z30 Unlocked Cellphone, 16GB, Black  ...            0.3400
# 42574  OtterBox 'Defender Series' Rugged and Protecti...  ...            0.6249
#
# [10 rows x 6 columns]

# %% [markdown]
# ### Veamos en donde hubo fallos en la predicción

# %%
missed = data[data['Rating'] == 1].sort_values(
    'valor_sentimiento', ascending = False).head(10)
missed
# Out:
#                                             Product Name  ... valor_sentimiento
# 45375  Nokia C3-01 Unlocked Touch and Type GSM Phone-...  ...            0.9983
# 14843  Moto G Play (4th gen.) - Black - 16 GB - Unloc...  ...            0.9970
# 29483                        Blu LIFE 8 Unlocked (White)  ...            0.9966
# 71594                         Blu LIFE 8 Unlocked (Pink)  ...            0.9966
# 26139  BLU Studio 5.0 C HD Smartphone - Unlocked - Ye...  ...            0.9963
# 43585  Blu Studio C Mini Quad Core, 4.7" IPS, Android...  ...            0.9905
# 40342  BLU PURE XL Smartphone - 4G LTE GSM Unlocked -...  ...            0.9900
# 26898           BLU Studio 6.0 Unlocked Cellphone, Black  ...            0.9892
# 3242            BLU Studio 6.0 Unlocked Cellphone, White  ...            0.9892
# 51177  Samsung Galaxy S5 SM-G900F 16GB Factory Unlock...  ...            0.9882
#
# [10 rows x 6 columns]

# %%
missed['Reviews'].values[2]
# Out:
# 'UPDATE:Don\'t buy this crap. A month after my 6 month warranty expired: - My wife\'s stopped charging. Touch screen randomly throws a fit and freaks out. - Mine, the speakerphone is completely dead/blew in it. Touchscreen issues as well.----------------My wife purchased the pink Blu Life 8 for herself about a week ago, after smashing her Samsung accidentally. She did about a full days worth of looking through different phones, and all the the different Blu brand phones (5.5, 6, 7, and 8) and she decided to spend the extra bucks for the 8. I work in IT and I was really impressed with the 8-core processor, and screen size for the price. It lacks the RAM of the super-high end phone but it sounded like a great amount of processing power. I was a little worried about battery life, but it\'s what she wanted and seemed reasonable enough.She received it and has been ecstatic with it so far. We had a little weirdness with the wifi initially. For some reason the OS kept setting itself to use a Static IP, instead of using DHCP, and this would have probably been a major deal if I wasn\'t in the IT field, but none the less I worked it out in about 60 seconds of fiddling with the networking settings, and it honestly could have been accidental on either of our part and not any fault of the phone. No issues with that since.As I mentioned previously I was a little worried about battery life having a large screen and an 8-core processor, but my wife claims that she only has to charge it once a day and is a heavy user, so I know I\'ll have no problems.The home/menu/back buttons on the bottom are very tiny compared to the space available. I\'m not sure why, they could be bigger. But this is the main concern I\'ve had with the phone when using my wife\'s. My wife doesn\'t have the problem as much as me, but they are simply very small, and because of the "lip" at the bottom (which will be the color you buy), a little awkwardly positioned versus other phones -- so it will take getting used to.The dual-sim capability isn\'t terribly useful for pretty much anyone in the US, but it is there none the less. It was hard tracking down the correct SIM card to work in this since I couldn\'t find what size it took. So for reference, it has two SIM slots -- one slot accepts standard size, and the other accepts mini-SIM. It does not accept nano SIM, but this wasn\'t a problem for us, I\'ve never even seen a nano-SIM from any US provider.It is a little frail -- I worry about breaking it, compared to my 1/2" thick rock solid cheap-o I have now, this thing feels very brittle as if it could bend or break easily, and cases are hard / next to impossible to find. Luckily, the shop I work for we cut-to-size tempered glass, so I\'m going to put some tempered glass on both of ours to try to make them last.This all sounds negative, but it\'s only because other than these minor issues -- the phone is PERFECT! Even if the price was 50% more, I would still say it was a fair deal. I have been using a $20.00 Bunk Android phone for the past few months, and loved my wife\'s Blu Life 8 so much I just went ahead and purchased the Orange one for myself! I can\'t wait. Why the Yellow is $100 more, I don\'t know, -- I wanted the yellow -- but I just got the orange one instead. Honestly for the price, as a hetro manly man, I would have gladly purchased a bright pink one with ponies and faires and proudly showed off my new phone to peers. It\'s that good.Overall:PROS: - Price price price. This is a crazy cheap phone, and I got both of them within 2 days through Amazon Prime. A few years ago I was oogling over $700 quad-core processors, and here is an octo-core (8-core) for well under $200.00. I feel like this is comparable to $500-$600 phones easily. My wife is using StraightTalk with her\'s currently, and I will be using Net10 when mine arrives. When both of our plans run out, I will be switching us to Net10\'s Family Plan which is only $75 a month for both. - With the octacore proce ...

# %%
sent.polarity_scores
# Out:
# 'great product   recommend'

# %%
sent.polarity_scores(missed['Reviews'].values[2])
# Out:
# {'compound': 0.999, 'neg': 0.056, 'neu': 0.806, 'pos': 0.138}

# %% [markdown]
# # Añadimos polaridad

# %%
data['positivos'] = [d['pos'] for d in sentiments]
data['negativos'] = [d['neg'] for d in sentiments]

# %%
data.corr()
# Out:
#                       Price    Rating  valor_sentimiento  positivos  negativos
# Price              1.000000  0.065987           0.033781   0.063587  -0.027952
# Rating             0.065987  1.000000           0.537247   0.504891  -0.425191
# valor_sentimiento  0.033781  0.537247           1.000000   0.589953  -0.581227
# positivos          0.063587  0.504891           0.589953   1.000000  -0.392113
# negativos         -0.027952 -0.425191          -0.581227  -0.392113   1.000000

# %%
# Visualizamos la relación con un mapa de calor 
g = data.groupby(['Rating','Brand Name'])['positivos'].mean().unstack()
sns.heatmap(g,
            linewidths=.5, 
            cmap="RdYlGn", 
            vmin = -0.5,
            vmax = .6)
plt.title('Heatmap Valor Sentimiento vs Rating por Marca');

# %%
g = data.groupby(['Brand Name'])[
  'positivos','negativos'].mean().sort_values('positivos')
                             
g['negativos'] = g['negativos']*-1                       
g.plot(kind='bar')
plt.ylim(-.6,.6)
plt.title('Polaridad por Marca')
plt.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
